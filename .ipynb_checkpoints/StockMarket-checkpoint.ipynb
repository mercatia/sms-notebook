# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates

# %%
r = requests.get("http://192.168.1.89:8081/api/v1/market")
r.json()
# Out:
# {'date': '2019-03-21T17:00:00Z',
#  'lastMonthAveragePrice': 58.73,
#  'marketTrajectory': 'NORMAL'}

# %%
r = requests.get("http://192.168.1.89:8081/api/v1/stocks/detailed")
df = pd.DataFrame(r.json())
news = df[df['ticker']=='AMZN']
pd.json_normalize(news,record_path=['newsHistory'])

#https://towardsdatascience.com/how-to-convert-json-into-a-pandas-dataframe-100b2ae1e0d8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 df = pd.DataFrame(r.json())
#       3 news = df[df['ticker']=='AMZN']
# ----> 4 pd.json_normalize(news,record_path=['newsHistory'])
#       6 #https://towardsdatascience.com/how-to-convert-json-into-a-pandas-dataframe-100b2ae1e0d8
#
# File ~/.cache/pypoetry/virtualenvs/sms-notebook-nIwzzPdF-py3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:519, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     516                 meta_vals[key].append(meta_val)
#     517             records.extend(recs)
# --> 519 _recursive_extract(data, record_path, {}, level=0)
#     521 result = DataFrame(records)
#     523 if record_prefix is not None:
#
# File ~/.cache/pypoetry/virtualenvs/sms-notebook-nIwzzPdF-py3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:501, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     499 else:
#     500     for obj in data:
# --> 501         recs = _pull_records(obj, path[0])
#     502         recs = [
#     503             nested_to_record(r, sep=sep, max_level=max_level)
#     504             if isinstance(r, dict)
#     505             else r
#     506             for r in recs
#     507         ]
#     509         # For repeating the metadata later
#
# File ~/.cache/pypoetry/virtualenvs/sms-notebook-nIwzzPdF-py3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:423, in json_normalize.<locals>._pull_records(js, spec)
#     417 def _pull_records(js: dict[str, Any], spec: list | str) -> list:
#     418     """
#     419     Internal function to pull field for records, and similar to
#     420     _pull_field, but require to return list. And will raise error
#     421     if has non iterable value.
#     422     """
# --> 423     result = _pull_field(js, spec, extract_record=True)
#     425     # GH 31507 GH 30145, GH 26284 if result is not list, raise TypeError if not
#     426     # null, otherwise return an empty list
#     427     if not isinstance(result, list):
#
# File ~/.cache/pypoetry/virtualenvs/sms-notebook-nIwzzPdF-py3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:400, in json_normalize.<locals>._pull_field(js, spec, extract_record)
#     398             result = result[field]
#     399     else:
# --> 400         result = result[spec]
#     401 except KeyError as e:
#     402     if extract_record:
#
# TypeError: string indices must be integers, not 'str'

# %%
r = requests.get("http://192.168.1.89:8081/api/v1/stocks/detailed")
j = r.json()
plt.figure(figsize=(25, 10),dpi=72) 
for stock in j:
   # print(stock['ticker'])
   if stock['ticker'] in ['AAPL','AMZN']:
       mh = pd.DataFrame(stock['priceHistory'])

       mh['marketDate'] = mh['marketDate'].apply(lambda x: datetime.fromisoformat(x))
       mh = mh.sort_values('marketDate', ascending=True).reset_index(drop=True)
       plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
       plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=5))
       plt.plot(mh['marketDate'],mh['stockPrice'],label=stock['ticker'])
       plt.gcf().autofmt_xdate()
       plt.xlabel('Date', fontsize=10)
       plt.ylabel('Price',fontsize=10)
       plt.legend(loc="upper left")


plt.show()

# %%
mh

r = requests.get("http://localhost:8080/api/v1/stocks/AAPL")
r.json()
# Out:
# {'ticker': 'AAPL',
#  'companyName': 'Apple',
#  'sector': 'Technology',
#  'marketCap': 'Large',
#  'price': 98.51,
#  'lastDayPrice': 98.35,
#  'percentChange': 0.16,
#  'momentum': 0,
#  'momentumStreakInDays': 2,
#  'volatileStock': 'VOLATILE',
#  'investorRating': 'Buy',
#  'newsHistory': [],
#  'earningsHistory': [{'estimatedEPS': 2.13,
#    'actualEPS': 2.7,
#    'reportMessage': 'Date: 3/1/1. Apple announces stable profits in new earnings report today. Their EPS of 2.7 fell in line with expectations of 2.13 EPS.',
#    'dateOfRelease': '3/1/1'}],
#  'priceHistory': [{'marketDate': '1/1/1', 'stockPrice': 101.37},
#   {'marketDate': '1/10/1', 'stockPrice': 95.09},
#   {'marketDate': '1/11/1', 'stockPrice': 95.51},
#   {'marketDate': '1/12/1', 'stockPrice': 98.73},
#   {'marketDate': '1/13/1', 'stockPrice': 99.73},
#   {'marketDate': '1/14/1', 'stockPrice': 102.25},
#   {'marketDate': '1/15/1', 'stockPrice': 103.06},
#   {'marketDate': '1/16/1', 'stockPrice': 106.22},
#   {'marketDate': '1/17/1', 'stockPrice': 108.52},
#   {'marketDate': '1/18/1', 'stockPrice': 111.09},
#   {'marketDate': '1/19/1', 'stockPrice': 108.94},
#   {'marketDate': '1/2/1', 'stockPrice': 100.71},
#   {'marketDate': '1/20/1', 'stockPrice': 111.36},
#   {'marketDate': '1/21/1', 'stockPrice': 110.81},
#   {'marketDate': '1/22/1', 'stockPrice': 110.58},
#   {'marketDate': '1/23/1', 'stockPrice': 107.36},
#   {'marketDate': '1/24/1', 'stockPrice': 107.86},
#   {'marketDate': '1/25/1', 'stockPrice': 107.33},
#   {'marketDate': '1/26/1', 'stockPrice': 110.71},
#   {'marketDate': '1/27/1', 'stockPrice': 108.37},
#   {'marketDate': '1/28/1', 'stockPrice': 108.29},
#   {'marketDate': '1/29/1', 'stockPrice': 107.54},
#   {'marketDate': '1/3/1', 'stockPrice': 100.46},
#   {'marketDate': '1/30/1', 'stockPrice': 109.0},
#   {'marketDate': '1/4/1', 'stockPrice': 101.15},
#   {'marketDate': '1/5/1', 'stockPrice': 99.97},
#   {'marketDate': '1/6/1', 'stockPrice': 96.19},
#   {'marketDate': '1/7/1', 'stockPrice': 97.62},
#   {'marketDate': '1/8/1', 'stockPrice': 96.35},
#   {'marketDate': '1/9/1', 'stockPrice': 94.13},
#   {'marketDate': '2/1/1', 'stockPrice': 113.66},
#   {'marketDate': '2/10/1', 'stockPrice': 105.99},
#   {'marketDate': '2/11/1', 'stockPrice': 108.81},
#   {'marketDate': '2/12/1', 'stockPrice': 109.02},
#   {'marketDate': '2/13/1', 'stockPrice': 111.42},
#   {'marketDate': '2/14/1', 'stockPrice': 109.1},
#   {'marketDate': '2/15/1', 'stockPrice': 111.21},
#   {'marketDate': '2/16/1', 'stockPrice': 110.03},
#   {'marketDate': '2/17/1', 'stockPrice': 109.82},
#   {'marketDate': '2/18/1', 'stockPrice': 110.53},
#   {'marketDate': '2/19/1', 'stockPrice': 110.37},
#   {'marketDate': '2/2/1', 'stockPrice': 114.99},
#   {'marketDate': '2/20/1', 'stockPrice': 112.53},
#   {'marketDate': '2/21/1', 'stockPrice': 111.03},
#   {'marketDate': '2/22/1', 'stockPrice': 107.66},
#   {'marketDate': '2/23/1', 'stockPrice': 106.78},
#   {'marketDate': '2/24/1', 'stockPrice': 107.73},
#   {'marketDate': '2/25/1', 'stockPrice': 105.48},
#   {'marketDate': '2/26/1', 'stockPrice': 101.41},
#   {'marketDate': '2/27/1', 'stockPrice': 98.92},
#   {'marketDate': '2/28/1', 'stockPrice': 99.43},
#   {'marketDate': '2/29/1', 'stockPrice': 98.98},
#   {'marketDate': '2/3/1', 'stockPrice': 113.63},
#   {'marketDate': '2/30/1', 'stockPrice': 99.74},
#   {'marketDate': '2/4/1', 'stockPrice': 111.82},
#   {'marketDate': '2/5/1', 'stockPrice': 109.45},
#   {'marketDate': '2/6/1', 'stockPrice': 107.71},
#   {'marketDate': '2/7/1', 'stockPrice': 109.27},
#   {'marketDate': '2/8/1', 'stockPrice': 108.7},
#   {'marketDate': '2/9/1', 'stockPrice': 107.38},
#   {'marketDate': '3/1/1', 'stockPrice': 100.82},
#   {'marketDate': '3/10/1', 'stockPrice': 94.72},
#   {'marketDate': '3/11/1', 'stockPrice': 93.18},
#   {'marketDate': '3/12/1', 'stockPrice': 92.78},
#   {'marketDate': '3/13/1', 'stockPrice': 93.53},
#   {'marketDate': '3/14/1', 'stockPrice': 91.92},
#   {'marketDate': '3/15/1', 'stockPrice': 95.04},
#   {'marketDate': '3/16/1', 'stockPrice': 97.78},
#   {'marketDate': '3/2/1', 'stockPrice': 101.02},
#   {'marketDate': '3/3/1', 'stockPrice': 101.28},
#   {'marketDate': '3/4/1', 'stockPrice': 97.67},
#   {'marketDate': '3/5/1', 'stockPrice': 94.84},
#   {'marketDate': '3/6/1', 'stockPrice': 94.18},
#   {'marketDate': '3/7/1', 'stockPrice': 93.37},
#   {'marketDate': '3/8/1', 'stockPrice': 94.11},
#   {'marketDate': '3/9/1', 'stockPrice': 95.16}]}
