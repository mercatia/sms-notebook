# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates

# %%
r = requests.get("http://localhost:8080/api/v1/market")
r.json()
# Out:
# {'date': '2019-01-01T08:00:00Z',
#  'lastMonthAveragePrice': 41.0,
#  'marketTrajectory': 'NORMAL'}

# %%
r = requests.get("http://localhost:8080/api/v1/stocks/detailed")
j = r.json()

for stock in j:
    if stock['ticker'] in ['AMZN']:
        print(stock)
# Out:
# {'ticker': 'AMZN', 'companyName': 'Amazon', 'sector': 'Technology', 'marketCap': 'Large', 'price': 84.71, 'lastDayPrice': 84.59, 'percentChange': 0.14, 'momentum': 0, 'momentumStreakInDays': 1, 'volatileStock': 'VOLATILE', 'investorRating': 'Buy', 'newsHistory': [], 'earningsHistory': [{'estimatedEPS': 2.82, 'actualEPS': 2.61, 'reportMessage': 'Date: 2019-03-01T00:00Z. Amazon announces stable profits in new earnings report today. Their EPS of 2.61 fell in line with expectations of 2.82 EPS.', 'dateOfRelease': '2019-03-01T00:00:00Z'}, {'estimatedEPS': 2.7, 'actualEPS': 3.7, 'reportMessage': 'Date: 2019-06-01T00:00Z. Amazon announces increased profits in new earnings report today, causing a spike in their stock price. Their EPS of 3.7 exceeded expectations of 2.7 EPS.', 'dateOfRelease': '2019-06-01T00:00:00Z'}], 'priceHistory': [{'marketDate': '2019-01-01T00:00:00Z', 'stockPrice': 95.0}, {'marketDate': '2019-01-02T00:00:00Z', 'stockPrice': 97.17}, {'marketDate': '2019-01-03T00:00:00Z', 'stockPrice': 94.89}, {'marketDate': '2019-01-04T00:00:00Z', 'stockPrice': 94.71}, {'marketDate': '2019-01-05T00:00:00Z', 'stockPrice': 95.03}, {'marketDate': '2019-01-06T00:00:00Z', 'stockPrice': 94.05}, {'marketDate': '2019-01-07T00:00:00Z', 'stockPrice': 91.05}, {'marketDate': '2019-01-08T00:00:00Z', 'stockPrice': 91.79}, {'marketDate': '2019-01-09T00:00:00Z', 'stockPrice': 92.5}, {'marketDate': '2019-01-10T00:00:00Z', 'stockPrice': 93.45}, {'marketDate': '2019-01-11T00:00:00Z', 'stockPrice': 92.38}, {'marketDate': '2019-01-12T00:00:00Z', 'stockPrice': 93.87}, {'marketDate': '2019-01-13T00:00:00Z', 'stockPrice': 95.25}, {'marketDate': '2019-01-14T00:00:00Z', 'stockPrice': 97.62}, {'marketDate': '2019-01-15T00:00:00Z', 'stockPrice': 96.9}, {'marketDate': '2019-01-16T00:00:00Z', 'stockPrice': 96.51}, {'marketDate': '2019-01-17T00:00:00Z', 'stockPrice': 94.18}, {'marketDate': '2019-01-18T00:00:00Z', 'stockPrice': 95.19}, {'marketDate': '2019-01-19T00:00:00Z', 'stockPrice': 96.56}, {'marketDate': '2019-01-20T00:00:00Z', 'stockPrice': 95.61}, {'marketDate': '2019-01-21T00:00:00Z', 'stockPrice': 96.91}, {'marketDate': '2019-01-22T00:00:00Z', 'stockPrice': 96.24}, {'marketDate': '2019-01-23T00:00:00Z', 'stockPrice': 98.49}, {'marketDate': '2019-01-24T00:00:00Z', 'stockPrice': 95.97}, {'marketDate': '2019-01-25T00:00:00Z', 'stockPrice': 96.51}, {'marketDate': '2019-01-26T00:00:00Z', 'stockPrice': 99.14}, {'marketDate': '2019-01-27T00:00:00Z', 'stockPrice': 99.12}, {'marketDate': '2019-01-28T00:00:00Z', 'stockPrice': 98.95}, {'marketDate': '2019-01-29T00:00:00Z', 'stockPrice': 98.3}, {'marketDate': '2019-01-30T00:00:00Z', 'stockPrice': 99.02}, {'marketDate': '2019-01-31T00:00:00Z', 'stockPrice': 98.63}, {'marketDate': '2019-02-01T00:00:00Z', 'stockPrice': 98.48}, {'marketDate': '2019-02-02T00:00:00Z', 'stockPrice': 96.53}, {'marketDate': '2019-02-03T00:00:00Z', 'stockPrice': 96.36}, {'marketDate': '2019-02-04T00:00:00Z', 'stockPrice': 96.13}, {'marketDate': '2019-02-05T00:00:00Z', 'stockPrice': 96.97}, {'marketDate': '2019-02-06T00:00:00Z', 'stockPrice': 96.3}, {'marketDate': '2019-02-07T00:00:00Z', 'stockPrice': 98.36}, {'marketDate': '2019-02-08T00:00:00Z', 'stockPrice': 100.77}, {'marketDate': '2019-02-09T00:00:00Z', 'stockPrice': 98.47}, {'marketDate': '2019-02-10T00:00:00Z', 'stockPrice': 98.17}, {'marketDate': '2019-02-11T00:00:00Z', 'stockPrice': 99.24}, {'marketDate': '2019-02-12T00:00:00Z', 'stockPrice': 102.17}, {'marketDate': '2019-02-13T00:00:00Z', 'stockPrice': 102.02}, {'marketDate': '2019-02-14T00:00:00Z', 'stockPrice': 99.73}, {'marketDate': '2019-02-15T00:00:00Z', 'stockPrice': 98.74}, {'marketDate': '2019-02-16T00:00:00Z', 'stockPrice': 101.29}, {'marketDate': '2019-02-17T00:00:00Z', 'stockPrice': 100.74}, {'marketDate': '2019-02-18T00:00:00Z', 'stockPrice': 101.72}, {'marketDate': '2019-02-19T00:00:00Z', 'stockPrice': 102.59}, {'marketDate': '2019-02-20T00:00:00Z', 'stockPrice': 101.44}, {'marketDate': '2019-02-21T00:00:00Z', 'stockPr ...

# %%
r = requests.get("http://localhost:8080/api/v1/stocks/detailed")
j = r.json()
plt.figure(figsize=(25, 10),dpi=72) 
for stock in j:
   # print(stock['ticker'])
   if stock['ticker'] in ['X']:
       mh = pd.DataFrame(stock['priceHistory'])

       mh['marketDate'] = mh['marketDate'].apply(lambda x: datetime.fromisoformat(x))
       mh = mh.sort_values('marketDate', ascending=True).reset_index(drop=True)
       plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
       plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=5))
       plt.plot(mh['marketDate'],mh['stockPrice'],label=stock['ticker'])
       plt.gcf().autofmt_xdate()
       plt.xlabel('Date', fontsize=10)
       plt.ylabel('Price',fontsize=10)
       plt.legend(loc="upper left")


plt.show()

# %%
mh

r = requests.get("http://localhost:8080/api/v1/stocks/AAPL")
r.json()
# Out:
# {'ticker': 'AAPL',
#  'companyName': 'Apple',
#  'sector': 'Technology',
#  'marketCap': 'Large',
#  'price': 98.51,
#  'lastDayPrice': 98.35,
#  'percentChange': 0.16,
#  'momentum': 0,
#  'momentumStreakInDays': 2,
#  'volatileStock': 'VOLATILE',
#  'investorRating': 'Buy',
#  'newsHistory': [],
#  'earningsHistory': [{'estimatedEPS': 2.13,
#    'actualEPS': 2.7,
#    'reportMessage': 'Date: 3/1/1. Apple announces stable profits in new earnings report today. Their EPS of 2.7 fell in line with expectations of 2.13 EPS.',
#    'dateOfRelease': '3/1/1'}],
#  'priceHistory': [{'marketDate': '1/1/1', 'stockPrice': 101.37},
#   {'marketDate': '1/10/1', 'stockPrice': 95.09},
#   {'marketDate': '1/11/1', 'stockPrice': 95.51},
#   {'marketDate': '1/12/1', 'stockPrice': 98.73},
#   {'marketDate': '1/13/1', 'stockPrice': 99.73},
#   {'marketDate': '1/14/1', 'stockPrice': 102.25},
#   {'marketDate': '1/15/1', 'stockPrice': 103.06},
#   {'marketDate': '1/16/1', 'stockPrice': 106.22},
#   {'marketDate': '1/17/1', 'stockPrice': 108.52},
#   {'marketDate': '1/18/1', 'stockPrice': 111.09},
#   {'marketDate': '1/19/1', 'stockPrice': 108.94},
#   {'marketDate': '1/2/1', 'stockPrice': 100.71},
#   {'marketDate': '1/20/1', 'stockPrice': 111.36},
#   {'marketDate': '1/21/1', 'stockPrice': 110.81},
#   {'marketDate': '1/22/1', 'stockPrice': 110.58},
#   {'marketDate': '1/23/1', 'stockPrice': 107.36},
#   {'marketDate': '1/24/1', 'stockPrice': 107.86},
#   {'marketDate': '1/25/1', 'stockPrice': 107.33},
#   {'marketDate': '1/26/1', 'stockPrice': 110.71},
#   {'marketDate': '1/27/1', 'stockPrice': 108.37},
#   {'marketDate': '1/28/1', 'stockPrice': 108.29},
#   {'marketDate': '1/29/1', 'stockPrice': 107.54},
#   {'marketDate': '1/3/1', 'stockPrice': 100.46},
#   {'marketDate': '1/30/1', 'stockPrice': 109.0},
#   {'marketDate': '1/4/1', 'stockPrice': 101.15},
#   {'marketDate': '1/5/1', 'stockPrice': 99.97},
#   {'marketDate': '1/6/1', 'stockPrice': 96.19},
#   {'marketDate': '1/7/1', 'stockPrice': 97.62},
#   {'marketDate': '1/8/1', 'stockPrice': 96.35},
#   {'marketDate': '1/9/1', 'stockPrice': 94.13},
#   {'marketDate': '2/1/1', 'stockPrice': 113.66},
#   {'marketDate': '2/10/1', 'stockPrice': 105.99},
#   {'marketDate': '2/11/1', 'stockPrice': 108.81},
#   {'marketDate': '2/12/1', 'stockPrice': 109.02},
#   {'marketDate': '2/13/1', 'stockPrice': 111.42},
#   {'marketDate': '2/14/1', 'stockPrice': 109.1},
#   {'marketDate': '2/15/1', 'stockPrice': 111.21},
#   {'marketDate': '2/16/1', 'stockPrice': 110.03},
#   {'marketDate': '2/17/1', 'stockPrice': 109.82},
#   {'marketDate': '2/18/1', 'stockPrice': 110.53},
#   {'marketDate': '2/19/1', 'stockPrice': 110.37},
#   {'marketDate': '2/2/1', 'stockPrice': 114.99},
#   {'marketDate': '2/20/1', 'stockPrice': 112.53},
#   {'marketDate': '2/21/1', 'stockPrice': 111.03},
#   {'marketDate': '2/22/1', 'stockPrice': 107.66},
#   {'marketDate': '2/23/1', 'stockPrice': 106.78},
#   {'marketDate': '2/24/1', 'stockPrice': 107.73},
#   {'marketDate': '2/25/1', 'stockPrice': 105.48},
#   {'marketDate': '2/26/1', 'stockPrice': 101.41},
#   {'marketDate': '2/27/1', 'stockPrice': 98.92},
#   {'marketDate': '2/28/1', 'stockPrice': 99.43},
#   {'marketDate': '2/29/1', 'stockPrice': 98.98},
#   {'marketDate': '2/3/1', 'stockPrice': 113.63},
#   {'marketDate': '2/30/1', 'stockPrice': 99.74},
#   {'marketDate': '2/4/1', 'stockPrice': 111.82},
#   {'marketDate': '2/5/1', 'stockPrice': 109.45},
#   {'marketDate': '2/6/1', 'stockPrice': 107.71},
#   {'marketDate': '2/7/1', 'stockPrice': 109.27},
#   {'marketDate': '2/8/1', 'stockPrice': 108.7},
#   {'marketDate': '2/9/1', 'stockPrice': 107.38},
#   {'marketDate': '3/1/1', 'stockPrice': 100.82},
#   {'marketDate': '3/10/1', 'stockPrice': 94.72},
#   {'marketDate': '3/11/1', 'stockPrice': 93.18},
#   {'marketDate': '3/12/1', 'stockPrice': 92.78},
#   {'marketDate': '3/13/1', 'stockPrice': 93.53},
#   {'marketDate': '3/14/1', 'stockPrice': 91.92},
#   {'marketDate': '3/15/1', 'stockPrice': 95.04},
#   {'marketDate': '3/16/1', 'stockPrice': 97.78},
#   {'marketDate': '3/2/1', 'stockPrice': 101.02},
#   {'marketDate': '3/3/1', 'stockPrice': 101.28},
#   {'marketDate': '3/4/1', 'stockPrice': 97.67},
#   {'marketDate': '3/5/1', 'stockPrice': 94.84},
#   {'marketDate': '3/6/1', 'stockPrice': 94.18},
#   {'marketDate': '3/7/1', 'stockPrice': 93.37},
#   {'marketDate': '3/8/1', 'stockPrice': 94.11},
#   {'marketDate': '3/9/1', 'stockPrice': 95.16}]}
